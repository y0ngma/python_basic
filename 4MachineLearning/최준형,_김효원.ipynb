# %%
import pandas as pd

# %%
import platform
import matplotlib
from matplotlib import font_manager, rc

# 시각
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# 워닝 방지
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./data/input/df_project.csv', encoding='euc-kr')

# %%
df_price = pd.read_csv('./data/input/소비자물가지수_2015100__20200417154941.csv', encoding='euc-kr')

# %%
# df_price_1 = df_price.iloc[:,:-3]

# %%
list_r = list() 
for i in df_price.loc[0]:
    print(i)
    list_r.append(i)
# Out:
# 서울특별시
# 99.49
# 99.56
# 99.47
# 99.63
# 99.82
# 99.83
# 100.26
# 100.51
# 100.36
# 100.33
# 100.18
# 100.55
# 100.63
# 101.03
# 100.71
# 100.88
# 100.92
# 100.87
# 100.76
# 101.15
# 101.72
# 101.86
# 101.73
# 101.89
# 102.77
# 103.0
# 103.07
# 102.98
# 103.12
# 102.97
# 103.28
# 103.89
# 103.78
# 103.52
# 102.86
# 103.16
# 103.57
# 104.32
# 104.31
# 104.55
# 104.56
# 104.19
# 104.15
# 105.04
# 105.7
# 105.33
# 104.77
# 104.49
# 104.54
# 105.07
# 104.86
# 105.26
# 105.31
# 105.17
# 104.91
# 105.21
# 105.57
# 105.8
# 105.24
# 105.44
# 106.09
# 106.06
# 105.97

# %%
len(list_r[1:])
# Out:
# 63

# %%
Price_Info = pd.Series(list_r[1:])

# %%
df['Price_Info']= Price_Info

# %%
df['Price_Info']
# Out:
# 0      99.49
# 1      99.56
# 2      99.47
# 3      99.63
# 4      99.82
#        ...
# 59    105.44
# 60    106.09
# 61    106.06
# 62    105.97
# 63       NaN
# Name: Price_Info, Length: 64, dtype: float64

# %%
df_price.columns
# Out:
# Index(['시도별', '2015. 01', '2015. 02', '2015. 03', '2015. 04', '2015. 05',
#        '2015. 06', '2015. 07', '2015. 08', '2015. 09', '2015. 10', '2015. 11',
#        '2015. 12', '2016. 01', '2016. 02', '2016. 03', '2016. 04', '2016. 05',
#        '2016. 06', '2016. 07', '2016. 08', '2016. 09', '2016. 10', '2016. 11',
#        '2016. 12', '2017. 01', '2017. 02', '2017. 03', '2017. 04', '2017. 05',
#        '2017. 06', '2017. 07', '2017. 08', '2017. 09', '2017. 10', '2017. 11',
#        '2017. 12', '2018. 01', '2018. 02', '2018. 03', '2018. 04', '2018. 05',
#        '2018. 06', '2018. 07', '2018. 08', '2018. 09', '2018. 10', '2018. 11',
#        '2018. 12', '2019. 01', '2019. 02', '2019. 03', '2019. 04', '2019. 05',
#        '2019. 06', '2019. 07', '2019. 08', '2019. 09', '2019. 10', '2019. 11',
#        '2019. 12', '2020. 01', '2020. 02', '2020. 03'],
#       dtype='object')

# %%
df= df[:60]
df
# Out:
#     year  month      Date  Temp_Average  High_Temp_Average  Low_Temp_Average  \
# 0   2015      1   2015-01          -0.9                3.6              -4.8
# 1   2015      2   2015-02           1.0                6.0              -2.9
# 2   2015      3   2015-03           6.3               12.4               1.0
# 3   2015      4   2015-04          13.3               18.8               8.4
# 4   2015      5   2015-05          18.9               24.9              13.6
# 5   2015      6   2015-06          23.6               29.5              18.9
# 6   2015      7   2015-07          25.8               30.0              22.6
# 7   2015      8   2015-08          26.3               30.8              22.8
# 8   2015      9   2015-09          22.4               28.1              17.5
# 9   2015     10   2015-10          15.5               21.2              10.8
# 10  2015     11   2015-11           8.9               12.7               5.9
# ...

# %%
df.columns
# Out:
# Index(['year', 'month', 'Date', 'Temp_Average', 'High_Temp_Average',
#        'Low_Temp_Average', 'Precipitation', 'Wind_Average', 'High_Wind',
#        'field_elevation_Average', 'High_field_elevation',
#        'Low_field_elevation', 'Sea_Level_Average', 'High_Sea_Level',
#        'Low_Sea_Level', 'Humidity_Average', 'Low_Humidity', 'Sunshine_Sum',
#        'Global_Solar_Radiation_Sum', 'Baechu_Wholesale', 'Pogi', 'Price_Info'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   year                        60 non-null     int64
#  1   month                       60 non-null     int64
#  2   Date                        60 non-null     object
#  3   Temp_Average                60 non-null     float64
#  4   High_Temp_Average           60 non-null     float64
#  5   Low_Temp_Average            60 non-null     float64
#  6   Precipitation               60 non-null     float64
#  7   Wind_Average                60 non-null     float64
#  8   High_Wind                   60 non-null     float64
#  9   field_elevation_Average     60 non-null     float64
#  10  High_field_elevation        60 non-null     float64
#  11  Low_field_elevation         60 non-null     float64
#  12  Sea_Level_Average           60 non-null     float64
# ...

# %% [markdown]
# # 컬럼 설명
# ---
#
# - Temp_Average
#     : 날짜 평균
#
# - High_Temp_Average
#     : 최저기온
#
# - Low_Temp_Average
#     : 최고기온
#
# - Precipitation
#     : 강수량
#
# - Wind_Average
#     : 평균풍속
#
# - High_Wind
#     : 최대풍속
#
# - field_elevation_Average
#     : 평균현지기압
#
# - High_field_elevation
#     : 최고현지기압
#
# - Low_field_elevation
#     : 최저현지기압
#
# - Sea_Level_Average
#     : 평균해면기압
#
# - High_Sea_Level
#     : 최고해면기압
#
# - Low_Sea_Level
#     : 최저해면기압
#
# - Humidity_Average
#     : 평균상대습도
#
# - Low_Humidity
#     : 최소상대습도
#
# - Sunshine_Sum
#     : 합계일조시간
#
# - Global_Solar_Radiation_Sum
#     : 합계전천일사량
#
# - year
#     : 년
#
# - month
#     : 월
#
# - Baechu_Wholesale
#     : 10kg
#
# - Pogi
#     : 포기 당

# %%
df['Baechu_Wholesale'].hist()

# %%
df.columns
# Out:
# Index(['year', 'month', 'Date', 'Temp_Average', 'High_Temp_Average',
#        'Low_Temp_Average', 'Precipitation', 'Wind_Average', 'High_Wind',
#        'field_elevation_Average', 'High_field_elevation',
#        'Low_field_elevation', 'Sea_Level_Average', 'High_Sea_Level',
#        'Low_Sea_Level', 'Humidity_Average', 'Low_Humidity', 'Sunshine_Sum',
#        'Global_Solar_Radiation_Sum', 'Baechu_Wholesale', 'Pogi', 'Price_Info'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(30,20))
ax = fig.gca()
df.hist(ax=ax)
plt.show()

# %%
ax = plt.subplot()
# ax = sns.distplot(df['평균'])
ax = sns.distplot(df['Pogi'])
plt.figure(figsize=(100, 30))

# %%
df
# Out:
#     year  month      Date  Temp_Average  High_Temp_Average  Low_Temp_Average  \
# 0   2015      1   2015-01          -0.9                3.6              -4.8
# 1   2015      2   2015-02           1.0                6.0              -2.9
# 2   2015      3   2015-03           6.3               12.4               1.0
# 3   2015      4   2015-04          13.3               18.8               8.4
# 4   2015      5   2015-05          18.9               24.9              13.6
# 5   2015      6   2015-06          23.6               29.5              18.9
# 6   2015      7   2015-07          25.8               30.0              22.6
# 7   2015      8   2015-08          26.3               30.8              22.8
# 8   2015      9   2015-09          22.4               28.1              17.5
# 9   2015     10   2015-10          15.5               21.2              10.8
# 10  2015     11   2015-11           8.9               12.7               5.9
# ...

# %%
# pair_grid = sns.PairGrid(df) 
# pair_grid = pair_grid.map_upper(sns.regplot) 
# pair_grid = pair_grid.map_lower(sns.kdeplot) 
# pair_grid = pair_grid.map_diag(sns.distplot, rug=True) 

# plt.show()

# %%
cols = df.columns[:-1]

# %%
for i in cols:
    scatter_plot = plt.figure()
    axes = scatter_plot.add_subplot(1,1,1)
    axes.scatter(df['Pogi'], df[i])
    plt.title('Scatter Plot')
    plt.xlabel('price')
    plt.ylabel(str(i))
#     print(i)

# %%
cols= df.columns[2:]

# %%
['Date', 'Temp_Average', 'High_Temp_Average', 'Low_Temp_Average',
       'Precipitation', 'Wind_Average', 'High_Wind', 'field_elevation_Average',
       'High_field_elevation', 'Low_field_elevation', 'Sea_Level_Average',
       'High_Sea_Level', 'Low_Sea_Level', 'Humidity_Average', 'Low_Humidity',
       'Sunshine_Sum', 'Global_Solar_Radiation_Sum', 'Baechu_Wholesale',
       'Pogi', 'Price_Info']
# Out:
# ['Date',
#  'Temp_Average',
#  'High_Temp_Average',
#  'Low_Temp_Average',
#  'Precipitation',
#  'Wind_Average',
#  'High_Wind',
#  'field_elevation_Average',
#  'High_field_elevation',
#  'Low_field_elevation',
#  'Sea_Level_Average',
#  'High_Sea_Level',
#  'Low_Sea_Level',
#  'Humidity_Average',
#  'Low_Humidity',
#  'Sunshine_Sum',
#  'Global_Solar_Radiation_Sum',
#  'Baechu_Wholesale',
#  'Pogi',
#  'Price_Info']

# %%
cols = [ 'Humidity_Average', 'Low_Humidity',
        'Global_Solar_Radiation_Sum', 'Baechu_Wholesale',
       'Pogi']

# %%
corr = df[cols].corr(method = 'pearson')

# %%
fig = plt.figure(figsize=(30,30))
ax = fig.gca()
sns.set(font_scale=1.5)
hm = sns.heatmap(corr.values,
                annot = True,
                fmt ='.2f',
                annot_kws ={'size':30},
                yticklabels=cols,
                xticklabels=cols,
                ax=ax)
plt.tight_layout()
plt.show()

# %%
cols
# Out:
# ['Humidity_Average',
#  'Low_Humidity',
#  'Global_Solar_Radiation_Sum',
#  'Baechu_Wholesale',
#  'Pogi']

# %%
df.corr()
# Out:
#                                 year     month  Temp_Average  \
# year                        1.000000  0.000000     -0.009562
# month                       0.000000  1.000000      0.266155
# Temp_Average               -0.009562  0.266155      1.000000
# High_Temp_Average          -0.013323  0.249064      0.997647
# Low_Temp_Average           -0.010279  0.277413      0.997946
# Precipitation               0.056549  0.150853      0.572769
# Wind_Average               -0.706980 -0.316630     -0.176554
# High_Wind                  -0.399772 -0.193619     -0.026869
# field_elevation_Average     0.009081 -0.017544     -0.934405
# High_field_elevation       -0.031783 -0.041496     -0.908658
# Low_field_elevation         0.003210 -0.022488     -0.730886
# Sea_Level_Average           0.008510 -0.031786     -0.941443
# High_Sea_Level             -0.029100 -0.052134     -0.917390
# Low_Sea_Level               0.000465 -0.038603     -0.752211
# ...

# %% [markdown]
# # ---

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler_columns =  [
        'Precipitation', 'High_Wind', 'High_field_elevation',
       'Low_field_elevation', 
        'Humidity_Average', 'Low_Humidity', 'Sunshine_Sum',
       'Global_Solar_Radiation_Sum', 'Baechu_Wholesale', 'Price_Info']
df[scaler_columns] = scaler.fit_transform(df[scaler_columns])

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt 

# sklearn
from sklearn import linear_model, preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import mean_squared_error
from math import sqrt
# %matplotlib inline

# %%
X = df[scaler_columns]
y = df['Pogi']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=33)

# %%
# 표준화 함수 정의
sc = preprocessing.StandardScaler()
# 데이터를 표준화
sc.fit(X_train)
X_train_std = sc.transform(X_train)
sc.fit(X_test)
X_test_std = sc.transform(X_test)

# %%
from sklearn import linear_model
from sklearn.linear_model import SGDRegressor
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import LinearRegression

# %%
# 실행해볼 리스트
# clf_ = linear_model.LinearRegression(normalize=False) 
# clf_ = linear_model.Ridge(alpha=.5)
# clf_ = linear_model.LassoLars(alpha=.1) 
# clf_ = RANSACRegressor(random_state=None) 
clf_ = KNeighborsRegressor(n_neighbors=5) # 15 
# clf_ = linear_model.Lasso(alpha=0.1,max_iter=5000)

# %%
clf_.fit(X_train, y_train)
y_pred  = clf_.predict(X_test)

# %% [markdown]
# ```
# # LinearRegression
#
# Mean Squared Error : 266014.0375088213
# Mean Absolute Error : 399.82507688995537
# train 학습 정확도 : 0.9222516820660789
# test 학습 정확도 : 0.7760012730409613
#
# # Ridge
#
# Mean Squared Error : 266014.0375088213
# Mean Absolute Error : 399.82507688995537
# train 학습 정확도 : 0.9222516820660789
# test 학습 정확도 : 0.7760012730409613
#
# # LassoLars
# Mean Squared Error : 281718.5169091243
# Mean Absolute Error : 414.28189866801455
# train 학습 정확도 : 0.9225007703315087
# test 학습 정확도 : 0.7627772213098356
#
# # RANSACRegressor
# Mean Squared Error : 115142.09507297874
# Mean Absolute Error : 293.67961791052693
# train 학습 정확도 : 0.8506285796353146
# test 학습 정확도 : 0.9030439034072082
#
# # KNeighborsRegressor=> n_neighbors=15
# Mean Squared Error : 417080.1837037038
# Mean Absolute Error : 526.288888888889
# train 학습 정확도 : 0.46664414581636326
# test 학습 정확도 : 0.648795112226461
#
# # KNeighborsRegressor=> n_neighbors=10
#
# Mean Squared Error : 335396.81000000006
# Mean Absolute Error : 535.3666666666667
# train 학습 정확도 : 0.6133681250528182
# test 학습 정확도 : 0.7175770904058733
#
# #  KNeighborsRegressor=> n_neighbors=5
#
# Mean Squared Error : 201480.73999999987
# Mean Absolute Error : 385.2333333333332
# train 학습 정확도 : 0.7378853434946766
# test 학습 정확도 : 0.8303419259772394
#
#
# # Lasso
#
# Mean Squared Error : 288850.0766973041
# Mean Absolute Error : 421.0654454800347
# train 학습 정확도 : 0.9225216966791545
# test 학습 정확도 : 0.7567720483169196
#
# #
#
# ```

# %%
# KNeighborsRegressor
print('Mean Squared Error :',mean_squared_error(y_test,y_pred))
print('Mean Absolute Error :',mean_absolute_error(y_test,y_pred))
print("train 학습 정확도 :", clf_.score(X_train, y_train)) 
print("test 학습 정확도 :", clf_.score(X_test, y_test))
# Out:
# Mean Squared Error : 373435.54
# Mean Absolute Error : 486.4111111111112
# train 학습 정확도 : 0.7300093669925536
# test 학습 정확도 : 0.6978012952478989

# %% [markdown]
# ---

# %%
# print( len(X_train),len(y_train), X_train,y_train)

# %%
# print(len(X_test),len(y_test), X_test, y_test)

# %%
lr = linear_model.LinearRegression()
model = lr.fit(X_train, y_train)

print(lr.coef_)
# Out:
# [ -93.66151799  164.67198095  202.61984841  -53.46794714   15.19079415
#    84.87524757 -156.62198736  280.94508159 1108.13924143  287.01440314]

# %%
# r2 score
print(model.score(X_train, y_train))
print(model.score(X_test, y_test))
# Out:
# 0.9377017728832715
# 0.7358342647298559

# %%
# C값의 범위를 설정(0.00001 ~ 10000) 
C_list = [10 **i for i in range(-5, 5)]
C_list
# Out:
# [1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]

# %%
# model = LogisticRegression(C=c, random_state=33) # 이게문제인것같아 42
# model.fit(X_train, y_train)

# print('(model.score(X_train, y_train)',model.score(X_train, y_train))
# print('model.score(X_test, y_test)',model.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-d523484a2dc1> in <module>
# ----> 1 model = LogisticRegression(C=c, random_state=33) # 이게문제인것같아 42
#       2 model.fit(X_train, y_train)
#       3
#       4 print('(model.score(X_train, y_train)',model.score(X_train, y_train))
#       5 print('model.score(X_test, y_test)',model.score(X_test, y_test))
#
# NameError: name 'c' is not defined

# %%
# for c in C_list:
#     model = LogisticRegression(C=c, random_state=33) # 이게문제인것같아 42
#     model.fit(X_train, y_train)
    
#     print('(model.score(X_train, y_train)',model.score(X_train, y_train))
#     print('model.score(X_test, y_test)',model.score(X_test, y_test))

# %%
# rmse
y_predictions = lr.predict(X_train)
print(sqrt(mean_squared_error(y_train, y_predictions)))
# Out:
# 311.8291760321689

# %%
y_predictions = lr.predict(X_test)
print(sqrt(mean_squared_error(y_test, y_predictions)))
# Out:
# 571.3467574052816

# %%
import statsmodels.api as sm

# %%
X_train = sm.add_constant(X_train)
model = sm.OLS(y_train, X_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Pogi   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     46.66
# Date:                Fri, 17 Apr 2020   Prob (F-statistic):           7.03e-16
# Time:                        17:11:27   Log-Likelihood:                -300.78
# No. Observations:                  42   AIC:                             623.6
# Df Residuals:                      31   BIC:                             642.7
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
# 다중 공선성
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()

vif['VIF Factor'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['features'] = X_train.columns
vif.round(1)
# Out:
#     VIF Factor                    features
# 0          1.1                       const
# 1          2.6               Precipitation
# 2          2.2                   High_Wind
# 3          6.0        High_field_elevation
# 4          3.5         Low_field_elevation
# 5          5.4            Humidity_Average
# 6          4.1                Low_Humidity
# 7          5.1                Sunshine_Sum
# 8          8.1  Global_Solar_Radiation_Sum
# 9          1.5            Baechu_Wholesale
# 10         2.0                  Price_Info
